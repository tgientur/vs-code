# %%
# %load_ext sql
# %config SqlMagic.autocommit = False

from prettytable import TableStyle
# %config SqlMagic.style = TableStyle.MARKDOWN

# %sql mysql+pymysql://root:123456@localhost
# Out:
# ERROR:root:The 'style' trait of a SqlMagic instance expected a unicode string, not the TableStyle <TableStyle.MARKDOWN: 13>.
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# SHOW DATABASES;
# Out:
#  * mysql+pymysql://root:***@localhost
# 10 rows affected.
# [('companies',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('product',),
#  ('sakila',),
#  ('student',),
#  ('student_db',),
#  ('sys',),
#  ('world',)]
